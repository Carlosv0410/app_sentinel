# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
im = Image.open('Zona de estudio\Zona_de_estudio2.png')
# Create figure and axes
fig, ax = plt.subplots(figsize = (18,15))
# Display the image
ax.imshow(im)
# Create a Rectangle patch
rect1 = patches.Rectangle((410, 80), 50, 40, linewidth=1, edgecolor='r', facecolor='none')
rect2 = patches.Rectangle((330, 280), 50, 40, linewidth=1, edgecolor='y', facecolor='none')
rect3 = patches.Rectangle((90, 690), 50, 40, linewidth=1, edgecolor='c', facecolor='none')
# Add the patch to the Axes
ax.add_patch(rect1)
ax.add_patch(rect2)
ax.add_patch(rect3)
plt.show()

# %%
import shapefile as shp  # Requires the pyshp package
import matplotlib.pyplot as plt

sf = shp.Reader("CONCESIONES_RIO_ANZU.shp")

plt.figure()
for shape in sf.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x,y)
plt.show()

# %%
shape.shape.points
# Out:
# [(856217.3459368055, 9883681.04855944),
#  (856216.1910496303, 9883080.829951512),
#  (856616.3381318459, 9883080.058025075),
#  (856613.2292268758, 9881479.464553984),
#  (856513.1921578266, 9881479.660185717),
#  (856513.973383671, 9881879.807851223),
#  (856313.8998448187, 9881880.197814418),
#  (856314.4840386473, 9882180.307614546),
#  (856114.4111992249, 9882180.69647737),
#  (856115.3814546866, 9882680.877812823),
#  (856015.3452845032, 9882681.0714441),
#  (856016.1185085156, 9883081.215914167),
#  (855916.0824379546, 9883081.408845354),
#  (855917.2374234381, 9883681.6244533),
#  (856217.3459368055, 9883681.04855944)]

# %%
import pandas as pd 
def read_shapefile(sf_shape):
    """
    Read a shapefile into a Pandas dataframe with a 'coords' 
    column holding the geometry information. This uses the pyshp
    package
    """

    fields = [x[0] for x in sf_shape.fields][1:]
    records = [y[:] for y in sf_shape.records()]
    #records = sf_shape.records()
    shps = [s.points for s in sf_shape.shapes()]
    df = pd.DataFrame(columns=fields, data=records)
    df = df.assign(coords=shps)
    return df

# %%
read_shapefile(sf)
# Out:
#           nam                                       com  \
# 0      400198                                VISTA ANZU
# 1   100000337                                    NAPO 1
# 2   100000338                                    NAPO 2
# 3   100000347                                    NAPO 8
# 4   100000465                             RIO ILA OESTE
# 5   100000311                 NUEVA ESPERANZA GADP NAPO
# 6   100000317                                 CRISTOBAL
# 7   100000476                                     CINDY
# 8   100000444                                   BERTA 1
# 9   100000450                              MORETE COCHA
# 10  100000456                                    GENIAL
# 11     290966  CONFLUENCIA ENTRE EL RIO ANZU Y RIO LLAN
# 12   20000158                             MOLINA GADPPZ
# 13  100000046                          MTOP EL CAPRICHO
# 14    1090036                        CAPRICHO GADP NAPO
# 15    1090028                               EL CAPRICHO
# ...
